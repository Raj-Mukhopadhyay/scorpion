# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %%
x_train = np.array([[2104, 5, 1, 45], [1416, 3, 2, 40], [852, 2, 1, 35]])
y_train = np.array([460, 232, 178])

# %%
print(x_train.shape)
# Out:
# (3, 4)

# %%
b = 785.1811367994083
w = np.array([ 0.39133535, 18.75376741, -53.36032453, -26.42131618])
print(f"w_init shape: {w.shape}, b_init type: {type(b)}")
# Out:
# w_init shape: (4,), b_init type: <class 'float'>

# %%
import regression as rg
rg.J_gen(x_train,y_train,w,b)
# Out:
# 1.5578904330213735e-12

# %%
def compute_gradient(x_train,y_train,w,b):
    alpha=10**(-6.6)
    xtemp=np.transpose(x_train)
    m=len(x_train)
    n=len(x_train[0])
    l=list()
    for x in x_train:
        l.append(np.dot(w,x)+b)
    y_pre=np.array(l)
    l1=list()
    for i in range(n):
        l1.append(np.sum(xtemp[i]*(y_pre-y_train)))
    derivative_jwrtw=(1/m)*np.array(l1)
    derivative_jwrtb=(1/m)*np.sum(y_pre-y_train)
    return (derivative_jwrtb,derivative_jwrtw)

# %%
#Compute and display gradient 
tmp_dj_db, tmp_dj_dw = compute_gradient(x_train, y_train, w, b)
print(f'dj_db at initial w,b: {tmp_dj_db}')
print(f'dj_dw at initial w,b: \n {tmp_dj_dw}')
# Out:
# dj_db at initial w,b: -1.6739251122999121e-06
# dj_dw at initial w,b:
#  [-2.72623577e-03 -6.27197263e-06 -2.21745571e-06 -6.92403379e-05]

# %%
w_final,b_final=rg.linear_gen(x_train,y_train)
print("+-------------------------------------------------+")
m=len(x_train)
for i in range(m):
    print(f"prediction: {np.dot(x_train[i], w_final) + b_final}, target value: {y_train[i]}")
print("+-------------------------------------------------+")
# Out:
# ------------------------------
# w---> [2.41334667e-01 5.58666667e-04 1.83666667e-04 6.03500000e-03]
# b--> 0.000145
#
# J-----> 2529.4629522316304
# count--> 0
#
# ------------------------------
# ------------------------------
# w---> [ 0.20226002  0.00063328 -0.0004225   0.00141917]
# b--> 4.65553203544732e-07
#
# J-----> 696.5286570158293
# count--> 50
#
# ------------------------------
# ------------------------------
# w---> [ 0.20235171  0.00079796 -0.00099658 -0.00219736]
# b--> -0.00011985961877688923
#
# J-----> 695.990315835203
# count--> 100
#
# ------------------------------
# ------------------------------
# w---> [ 0.20244319  0.00096258 -0.00157024 -0.00580581]
# b--> -0.00023990053217367948
#
# J-----> 695.4543329617294
# count--> 150
#
# ------------------------------
# ------------------------------
# w---> [ 0.20253446  0.00112715 -0.00214349 -0.00940619]
# b--> -0.0003596578183953629
#
# J-----> 694.9206979323068
# count--> 200
#
# ------------------------------
# ...
