# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("polynomial_train.csv")
data.head()
# Out:
#    Unnamed: 0            A            B           C         label
# 0           0 -1113.924581   952.105404 -276.045881 -1.294289e+03
# 1           1 -2229.480228  1111.488568  -93.454107 -2.714687e+04
# 2           2  2717.257713    53.431237 -179.228591  6.474300e+04
# 3           3 -1638.783965  -632.919447 -106.170237 -7.349871e+03
# 4           4  5173.934338  -721.895577  -75.074840  1.651328e+06

# %%
l=list()
for c in range(65,68):
    l.append(data[chr(c)])
xtemp=np.array(l)
y_train=np.array(data['label'])

# %%
print(xtemp)
# Out:
# [[-1113.92458108 -2229.48022767  2717.25771283 ...  -533.44699332
#    1810.49910349  -861.91021653]
#  [  952.10540425  1111.48856784    53.43123706 ...  1171.45733504
#    -424.11169601   257.2959923 ]
#  [ -276.04588086   -93.4541072   -179.22859092 ...  -130.84092473
#    -128.33498562  -176.1228714 ]]

# %%
xtemp.shape
# Out:
# (3, 50000)

# %%
plt.scatter(xtemp[1],y_train,marker='x',c='r')

# %%
x=np.array(range(-10,11))
y=x**5
plt.plot(x,y)
