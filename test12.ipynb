# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cluster as cl

# %%
data=pd.read_csv("clustering_train.csv")
data.head()
# Out:
#    Unnamed: 0  pixel1  pixel2
# 0           1     5.0     5.0
# 1           2     1.0     2.0
# 2           3     5.5     4.5
# 3           4     2.0     2.0
# 4           5     1.0     1.0

# %%
l=list()
for c in range(1,3):
    l.append(data[f"pixel{c}"])
xtemp=np.array(l)
x_train=np.transpose(xtemp)

# %%
cl.classify_kmeans(x_train,3)
# Out:
# -------------
# dist--->[5.01601435 2.77856078 2.57689736]
# --------------
# -------------
# dist--->[4.40509616 3.29256275 2.31529026]
# --------------
# -------------
# dist--->[4.30228067 3.36943039 2.31529026]
# --------------
# -------------
# dist--->[4.30228067 3.36943039 2.31529026]
# --------------
