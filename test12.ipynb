# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cluster as cl

# %%
data=pd.read_csv("clustering_train.csv")
data.head()
# Out:
#    Unnamed: 0  pixel1  pixel2
# 0           1     5.0     5.0
# 1           2     1.0     2.0
# 2           3     5.5     4.5
# 3           4     2.0     2.0
# 4           5     1.0     1.0

# %%
l=list()
for c in range(1,3):
    l.append(data[f"pixel{c}"])
xtemp=np.array(l)
x_train=np.transpose(xtemp)

# %%
cl.progress(x_train,2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_16795/1971192378.py in <module>
# ----> 1 cl.progress(x_train,2)
#
# ~/Programs/Artificial_Intelligence/scorpion/cluster.py in progress(x_train, k)
#      29     for i in range(m):
#      30         for j in range(k):
# ---> 31             if label[i]==j:
#      32                 l[j][0].append(xtemp[0][i])
#      33                 l[j][1].append(xtemp[1][i])
#
# NameError: name 'label' is not defined

# %%
cl.classify_kmeans(x_train)
# Out:
# -------------
# dist--->[4.41 7.61]
# --------------
# -------------
# dist--->[2.22847222 9.14256944]
# --------------
# -------------
# dist--->[ 1.8964497 10.3961157]
# --------------
# -------------
# dist--->[ 1.8964497 10.3961157]
# --------------
# -------------
# dist--->[ 1.8964497 10.3961157]
# --------------
# -------------
# dist--->[ 1.8964497 10.3961157]
# --------------
# -------------
# dist--->[ 1.8964497 10.3961157]
# --------------
# -------------
# dist--->[ 1.8964497 10.3961157]
# --------------
# -------------
# dist--->[ 1.8964497 10.3961157]
# --------------
# -------------
# dist--->[ 1.8964497 10.3961157]
# --------------
# -------------
# dist--->[ 1.8964497 10.3961157]
# --------------
# -------------
# dist--->[ 1.8964497 10.3961157]
# --------------
# -------------
# dist--->[ 1.8964497 10.3961157]
# --------------
# -------------
# dist--->[ 1.8964497 10.3961157]
# --------------
# -------------
# dist--->[ 1.8964497 10.3961157]
# --------------
# ...
