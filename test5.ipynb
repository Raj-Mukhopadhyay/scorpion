# %%
import numpy as np
import pandas as pd
data=pd.read_csv("linear_train.csv")
data.head()
# Out:
#    Unnamed: 0           A           B          C         D          E  \
# 0           0 -284.685568  284.567363  18.462706  0.012380 -52.394580
# 1           1 -428.480005  307.240676  22.632897 -0.099657   6.294685
# 2           2  -25.800879  237.433758  -0.467505 -0.115813  -7.837079
# 3           3 -292.645787  249.444200  -3.661449  0.020113  -4.273514
# 4           4 -264.114362  259.031693 -17.772049 -0.108774   6.512923
#
#            F           G          H           I  ...          L          M  \
# 0  -0.942413    6.746190  19.595626  554.989342  ...  33.451992  -9.171214
# 1  30.440746   95.919775 -52.450992 -872.531179  ...  14.848331 -33.556867
# 2  21.598922  158.095089   2.554397  136.298244  ... -12.662449  28.956309
# 3  21.421400   71.012817  49.089192 -444.041731  ...  -1.741291 -65.225030
# 4  13.657296   78.446286  20.942401 -257.340694  ...  17.309833  17.309769
#
#              N            O          P           Q          R           S  \
# ...

# %%
l=list()
for c in range(65,85):
    l.append(data[chr(c)])
x_train=np.transpose(np.array(l))
y_train=np.array(data['label'])

# %%
import regression as rg
w_final,b_final=rg.linear_gen(x_train,y_train)
print("+-------------------------------------------------+")
m=len(x_train)
for i in range(m):
    print(f"prediction: {np.dot(x_train[i], w_final) + b_final}, target value: {y_train[i]}")
print("+-------------------------------------------------+")
# Out:
# ------------------------------
# w---> [5.10871618e-03 4.52988623e-04 6.89409913e-04 5.73153240e-08
#  1.23134605e-04 8.82413658e-05 5.11901942e-04 2.24009282e-04
#  1.48552727e-03 5.20162325e-04 2.79725861e-04 2.70806590e-04
#  2.79824509e-05 1.16028063e-02 7.62549079e-04 3.38014245e-04
#  9.34638395e-05 2.38655198e-04 1.15233008e-03 2.24657097e-04]
# b--> -9.184731197434501e-08
#
# J-----> 29717.654750861908
# count--> 0
#
# ------------------------------
# ------------------------------
# w---> [1.62950325e-01 2.22783779e-02 3.51806616e-02 2.83722351e-06
#  6.36467278e-03 4.43373438e-03 2.56383154e-02 1.13453447e-02
#  4.72776852e-02 2.11520697e-02 1.37008411e-02 1.36838703e-02
#  1.28423870e-03 1.39268405e-01 2.31465757e-02 1.69885923e-02
#  2.15307887e-03 1.21715329e-02 5.18538770e-02 8.51119856e-03]
# b--> -8.148618055486344e-06
#
# J-----> 24107.190385364953
# count--> 50
#
# ------------------------------
# ...

# %%
import regression as rg
rg.determine_alpha(x_train,y_train)
# Out:
# [1.365650734930508, 1.3656503918945568, 1.3656500488586871, 1.365649705822909, 1.3656493627872055, 1.3656490197515905, 1.36564867671607, 1.3656483336806278, 1.3656479906452814, 1.3656476476100083, 1.3656473045748385, 1.3656469615397444, 1.3656466185047362, 1.365646275469819, 1.3656459324349755, 1.3656455894002275, 1.3656452463655608, 1.3656449033309859, 1.365644560296507, 1.365644217262095, 1.3656438742277746, 1.3656435311935435, 1.3656431881594022, 1.365642845125345, 1.3656425020913623, 1.3656421590574737, 1.3656418160236785, 1.3656414729899673, 1.3656411299563334, 1.3656407869228009, 1.3656404438893335, 1.3656401008559658, 1.365639757822684, 1.3656394147894841, 1.3656390717563751, 1.3656387287233502, 1.3656383856904095, 1.3656380426575576, 1.3656376996247912, 1.3656373565921118, 1.365637013559514, 1.3656366705270038, 1.3656363274945875, 1.365635984462242, 1.365635641429996, 1.3656352983978326, 1.3656349553657523, 1.365634612333767, 1.365634269301854, 1.3656339262700417, 1.365633583
# ...
